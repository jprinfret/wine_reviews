# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(pd.read_csv('parsed_wine_ratings.csv'))

# %%
df.vintage=df.vintage.astype('str')

# %%
df.apply(lambda x: x.astype('str'))
# Out:
#          country points price           province             region_1  \
# 0          Italy     87  20.0  Sicily & Sardinia                 Etna
# 1       Portugal     87  15.0              Douro                Douro
# 2             US     87  14.0             Oregon    Willamette Valley
# 3             US     87  13.0           Michigan  Lake Michigan Shore
# 4             US     87  65.0             Oregon    Willamette Valley
# ...          ...    ...   ...                ...                  ...
# 129902   Germany     90  28.0              Mosel                Mosel
# 129903        US     90  75.0             Oregon               Oregon
# 129904    France     90  30.0             Alsace               Alsace
# 129905    France     90  32.0             Alsace               Alsace
# 129906    France     90  21.0             Alsace               Alsace
#
#                taster_name                                              title  \
# ...

# %%
vintages = df['vintage']

# %%
parsed_vintages = []
for vintage in vintages:
    if len(vintage) < 4:
        parsed_vintages.append(np.nan)
    elif len(vintage) > 4:
        parsed_vintages.append(vintage[:4])
    elif vintage in ['10.0', '12.0', '331.']:
        parsed_vintages.append(np.nan)
    else:
        parsed_vintages.append(vintage)

# %%
df.drop('vintage', axis=1, inplace=True)

# %%
df['vintage'] = parsed_vintages

# %%
df.dropna(inplace=True)

# %%
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)

# %%
df[df['vintage']=='331.']
# Out:
#      country  points  price    province    region_1 taster_name  \
# 3422      US      88   10.0  California  California  Jim Gordon
#
#                                                   title    variety vintage
# 3422  Dark Horse NV Big Red Blend No 33-1 Red (Calif...  Red Blend    331.

# %%
df.drop(index=3422, inplace=True)

# %%
df.vintage=df.vintage.astype('float')

# %%
df[df['vintage']<1950]
# Out:
#        country  points  price           province              region_1  \
# 331      Spain      82   13.0          Catalonia                  Cava
# 970      Italy      88   24.0  Sicily & Sardinia                  Etna
# 1293        US      86   10.0         Washington            Washington
# 2070     Spain      85   16.0          Catalonia                  Cava
# 2136        US      88   10.0         Washington  Columbia Valley (WA)
# ...        ...     ...    ...                ...                   ...
# 124263  France      94   63.0          Champagne             Champagne
# 124384   Italy      85   30.0     Southern Italy     Fiano di Avellino
# 124466      US      85   10.0         Washington            Washington
# 124639   Italy      87   18.0            Tuscany               Toscana
# 125300      US      89   18.0           New York          Finger Lakes
#
#                taster_name                                              title  \
# ...

# %%
vintages = df['vintage']
parsed_vintages = []
for vintage in vintages:
    if vintage > 2019 or vintage < 1950:
        parsed_vintages.append(np.nan)
    else:
        parsed_vintages.append(vintage)

# %%
df.drop('vintage', axis=1, inplace=True)

# %%
df['vintage'] = parsed_vintages

# %%
df.dropna(inplace=True)

# %%
df.vintage=df.vintage.astype(int)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (114804, 9)

# %%
variety_dict = {
    'White Blend' : 'white_blend',
    'Portuguese Red' : 'red_blend',
    'Pinot Gris' : 'pinot_grigio',
    'Riesling' : 'riesling',
    'Pinot Noir' : 'pinot_noir',
    'Tempranillo-Merlot' : 'merlot',
    'Frappato' : np.nan,
    'Gewürztraminer' : 'riesling',
    'Cabernet Sauvignon': 'cabernet_sauvignon',
    'Nerello Mascalese' : 'pinot noir',
    'Chardonnay' : 'chardonnay',
    'Malbec': 'malbec',
    'Tempranillo Blend': 'red_blend',
    'Meritage': 'red_blend',
    'Red Blend': 'red_blend',
    'Merlot': 'merlot',
    "Nero d'Avola": 'cabernet_sauvignon',
    'Chenin Blanc': 'sauvignon_blanc',
    'Gamay': 'pinot_noir',
    'Sauvignon Blanc': 'sauvignon_blanc',
    'Viognier-Chardonnay': 'chardonnay',
    'Primitivo': 'zinfandel',
    'Catarratto': 'chardonnay',
    'Inzolia': np.nan,
    'Petit Verdot': 'red_blend',
    'Monica': np.nan,
    'Bordeaux-style White Blend': 'white_blend',
    'Grillo': 'sauvignon_blanc',
    'Sangiovese': 'cabernet_sauvignon',
    'Cabernet Franc': 'cabernet_sauvignon',
    'Bordeaux-style Red Blend': 'red_blend',
    'Aglianico': 'cabernet_sauvignon',
    'Petite Sirah': 'cabernet_sauvignon',
    'Touriga Nacional': 'cabernet_sauvignon',
    'Carmenère': 'cabernet_sauvignon',
    'Albariño': 'sauvignon_blanc',
    'Petit Manseng': np.nan,
    'Rosé': 'rosé',
    'Zinfandel': 'zinfandel',
    'Vernaccia': 'sauvignon_blanc',
    'Rosato': 'rosé',
    'Grüner Veltliner': 'riesling',
    'Viognier': 'chardonnay',
    'Vermentino': 'sauvignon_blanc',
    'Syrah': 'cabernet_sauvignon',
    'Nebbiolo': 'pinot_noir',
    'Shiraz-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Pinot Blanc': 'pinot_grigio',
    'Alsace white blend': 'white_blend',
    'Barbera': 'zinfandel',
    'Rhône-style Red Blend': 'red_blend',
    'Portuguese White': 'white_blend',
    'Graciano': np.nan,
    'Tannat-Cabernet': np.nan,
    'Sauvignon': 'sauvignon_blanc',
    'Sangiovese Grosso': 'cabernet_sauvignon',
    'Torrontés': 'riesling',
    'Prugnolo Gentile': np.nan,
    'G-S-M': 'red_blend',
    'Verdejo': 'sauvignon_blanc',
    'Fumé Blanc': 'sauvignon_blanc',
    'Furmint': np.nan,
    'Pinot Bianco': 'pinot_grigio',
    'Bonarda': 'red_blend',
    'Shiraz': 'cabernet_sauvignon',
    'Montepulciano': 'cabernet_sauvignon',
    'Grenache': 'cabernet_sauvignon',
    'Ugni Blanc-Colombard': np.nan,
    'Syrah-Viognier': np.nan,
    'Blaufränkisch': 'pinot_noir',
    'Friulano': 'sauvignon_blanc',
    'Assyrtico': np.nan,
    'Carignan-Grenache': np.nan,
    'Sagrantino': 'red_blend',
    'Savagnin': np.nan,
    'Cabernet Sauvignon-Syrah': 'cabernet_sauvignon',
    'Prosecco': np.nan,
    'Vignoles': np.nan,
    'Shiraz-Viognier': np.nan,
    'Garganega': 'sauvignon_blanc',
    'Pinot Grigio': 'pinot_grigio',
    'Grenache Blanc': 'sauvignon_blanc',
    'Tempranillo': 'pinot_noir',
    'Sparkling Blend': np.nan,
    'Zierfandler': 'zinfandel',
    'Cortese': np.nan,
    'Mencía': 'pinot_noir',
    'Zweigelt': 'malbec',
    'Melon': 'pinot_grigio',
    'Rhône-style White Blend': 'white_blend',
    'Vidal': np.nan,
    'Champagne Blend': np.nan,
    'Cannonau': np.nan,
    'Verdelho': np.nan,
    'Marsanne': np.nan,
    'Scheurebe': np.nan,
    'Kerner': np.nan,
    'Syrah-Grenache': np.nan,
    'Dolcetto': 'cabernet_sauvignon',
    'Vilana': np.nan,
    'Glera': np.nan,
    'Viura': 'white_blend',
    'Garnacha Tintorera': np.nan,
    'Pinot Nero': 'pinot_noir',
    'Roter Veltliner': np.nan,
    'Pinotage': 'cabernet_sauvignon',
    'Sémillon': 'chardonnay',
    'Pinot Noir-Gamay': np.nan,
    'Antão Vaz': np.nan,
    'Cabernet Sauvignon-Carmenère': np.nan,
    'Verdejo-Viura': np.nan,
    'Verduzzo': np.nan,
    'Verdicchio': 'sauvignon_blanc',
    'Silvaner': np.nan,
    'Colombard': np.nan,
    'Carricante': np.nan,
    'Sylvaner': np.nan,
    'Fiano': 'white_blend',
    'Früburgunder': np.nan,
    'Sousão': np.nan,
    'Roussanne': 'chardonnay',
    'Avesso': np.nan,
    'Cinsault': np.nan,
    'Tinta Miúda': np.nan,
    'Muscat Blanc à Petits Grains': np.nan,
    'Monastrell': 'pinot_noir',
    'Xarel-lo': np.nan,
    'Trebbiano': 'pinot_grigio',
    "Corvina, Rondinella, Molinara" : 'red_blend',
    'Port': np.nan,
    'Chenin Blanc-Chardonnay': 'chardonnay',
    'Insolia': np.nan,
    'Merlot-Malbec': np.nan,
    'Ribolla Gialla': np.nan,
    'Cabernet Sauvignon-Merlot': 'merlot',
    'Weissburgunder': np.nan,
    'Roditis': np.nan,
    'Traminer': np.nan,
    'Papaskarasi': np.nan,
    'Tannat-Syrah': np.nan,
    'Marsanne-Roussanne': np.nan,
    'Charbono': np.nan,
    'Merlot-Argaman': np.nan,
    'Greco': 'white_blend',
    'Prié Blanc': np.nan,
    'Provence red blend': 'red_blend',
    'Tannat': 'merlot',
    'Zibibbo': np.nan,
    'Falanghina': np.nan,
    'Garnacha': 'sauvignon_blanc',
    'Negroamaro': 'zinfandel',
    'Mourvèdre': 'red_blend',
    'Syrah-Cabernet': 'cabernet_sauvignon',
    'Müller-Thurgau': np.nan,
    'Pinot Meunier': np.nan,
    'Cabernet Sauvignon-Sangiovese': 'cabernet_sauvignon',
    'Austrian Red Blend': 'red_blend',
    'Teroldego': np.nan,
    'Pansa Blanca': np.nan,
    'Muskat Ottonel': np.nan,
    'Sauvignon Blanc-Semillon': 'sauvignon_blanc',
    'Claret': np.nan,
    'Semillon-Sauvignon Blanc': 'sauvignon_blanc',
    'Bical': np.nan,
    'Moscatel': np.nan,
    'Rosado': np.nan,
    'Viura-Chardonnay': 'chardonnay',
    'Baga': np.nan,
    'Malvasia Bianca': np.nan,
    'Gelber Muskateller': np.nan,
    'Malbec-Merlot': 'merlot',
    'Monastrell-Syrah': 'cabernet_sauvignon',
    'Malbec-Tannat': 'merlot',
    'Malbec-Cabernet Franc': 'merlot',
    'Moscato': 'zinfandel',
    'Turbiana': 'sauvignon_blanc',
    'Refosco': np.nan,
    'Alvarinho': 'white_blend',
    'Manzoni': np.nan,
    'Aragonês': np.nan,
    'Agiorgitiko': np.nan,
    'Muscat': 'riesling',
    'Malagousia': np.nan,
    'Assyrtiko': np.nan,
    'Ruché': np.nan,
    'Welschriesling': 'riesling',
    'Tinta de Toro': 'pinot_noir',
    'Rieslaner': np.nan,
    'Traminette': np.nan,
    'Chambourcin': np.nan,
    'Nero di Troia': np.nan,
    'Lambrusco di Sorbara': np.nan,
    'Cesanese': np.nan,
    'Feteasca Neagra': np.nan,
    'Lagrein': np.nan,
    'Tinta Fina': np.nan,
    'St. Laurent': np.nan,
    'Marsanne-Viognier': np.nan,
    'Cabernet Sauvignon-Shiraz': 'cabernet_sauvignon',
    'Syrah-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Gewürztraminer-Riesling': 'riesling',
    'Pugnitello': np.nan,
    'Cerceal': np.nan,
    'Touriga Nacional Blend': np.nan,
    'Austrian white blend': 'white_blend',
    'Tocai': np.nan,
    'Tinta Roriz': np.nan,
    'Chardonnay-Viognier': np.nan,
    'Fernão Pires': np.nan,
    'Cabernet Franc-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Grenache-Syrah': np.nan,
    'Seyval Blanc': np.nan,
    'Muscat Canelli': np.nan,
    'Cabernet Merlot': 'merlot',
    'Tempranillo-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Arinto': np.nan,
    'Aragonez': np.nan,
    'Merlot-Cabernet Franc': 'merlot',
    'Syrah-Petite Sirah': 'cabernet_sauvignon',
    'Cabernet Blend': 'cabernet_sauvignon',
    'Maturana': np.nan,
    'Pecorino': np.nan,
    'Rotgipfler': np.nan,
    'Kinali Yapincak': 1,
    'Cabernet Franc-Carmenère': np.nan,
    'Magliocco': np.nan,
    'Gamay Noir': np.nan,
    'Sauvignon Gris': np.nan,
    'Spätburgunder': np.nan,
    'Picpoul': np.nan,
    'Albanello': np.nan,
    'Arneis': np.nan,
    'Malvasia': np.nan,
    'Plavac Mali': np.nan,
    'Lemberger': np.nan,
    'Saperavi': np.nan,
    'Altesse': np.nan,
    'Blanc du Bois': np.nan,
    'Provence white blend': 'white_blend',
    'Nosiola': np.nan,
    'Dornfelder': np.nan,
    'Roussanne-Viognier': np.nan,
    'Godello': 'pinot_grigio',
    'Mondeuse': np.nan,
    'Perricone': np.nan,
    'Auxerrois': np.nan,
    'Syrah-Merlot': 'merlot',
    'Albana': np.nan,
    'Muskat': np.nan,
    'Cabernet Sauvignon-Malbec': 'cabernet_sauvignon',
    'Tinto Fino': 'cabernet_sauvignon',
    'Malbec-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Moschofilero': np.nan,
    'Grechetto': np.nan,
    'Encruzado': np.nan,
    'Carignano': np.nan,
    'Cabernet Franc-Merlot': 'merlot',
    'Torbato': np.nan,
    'Syrah-Petit Verdot': np.nan,
    'Garnacha Blanca': np.nan,
    'Pallagrello': np.nan,
    'Morava': np.nan,
    'Syrah-Mourvèdre': np.nan,
    'Aleatico': np.nan,
    'Carcajolu': np.nan,
    'Kisi': np.nan,
    'Vidal Blanc': np.nan,
    'Shiraz-Grenache': np.nan,
    'Grenache-Carignan': np.nan,
    'Nascetta': np.nan,
    'Portuguese Sparkling': np.nan,
    'Siria': np.nan,
    'Malbec-Syrah': 'malbec',
    'Asprinio': np.nan,
    'Feteascǎ Regalǎ': np.nan,
    'Marselan': np.nan,
    'Tocai Friulano': np.nan,
    'Schiava': np.nan,
    'Alfrocheiro': np.nan,
    'Chardonnay-Semillon': np.nan,
    'Corvina': np.nan,
    'Norton': np.nan,
    'Alicante Bouschet': np.nan,
    'Tokaji': np.nan,
    'Moscadello': np.nan,
    'Cabernet Sauvignon-Tempranillo': np.nan,
    'Carignan': np.nan,
    'Loureiro-Arinto': np.nan,
    'Lambrusco Grasparossa': np.nan,
    'Cabernet-Syrah': np.nan,
    'Sauvignon Blanc-Chardonnay': np.nan,
    'Symphony': np.nan,
    'Edelzwicker': np.nan,
    'Black Muscat': np.nan,
    'Grenache Noir': np.nan,
    'Durella': np.nan,
    'Xinomavro': np.nan,
    'Tinto del Pais': np.nan,
    'Merlot-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Cercial': np.nan,
    'Johannisberg Riesling': 'riesling',
    'Petite Verdot': np.nan,
    'Passerina': np.nan,
    'Valdiguié': np.nan,
    'Colombard-Sauvignon Blanc': 'sauvignon_blanc',
    'Kangoun': np.nan,
    'Loureiro': np.nan,
    'Posip': np.nan,
    'Uva di Troia': np.nan,
    'Gros and Petit Manseng': np.nan,
    'Jacquère': np.nan,
    'Kalecik Karasi': np.nan,
    'Karasakiz': np.nan,
    'Mourvèdre-Syrah': np.nan,
    'Negrette': np.nan,
    'Zierfandler-Rotgipfler': np.nan,
    'Clairette': np.nan,
    'País': np.nan,
    'Mauzac': np.nan,
    'Pinot Auxerrois': np.nan,
    'Chenin Blanc-Sauvignon Blanc': np.nan,
    'Diamond': np.nan,
    'Marzemino': np.nan,
    'Tinta Barroca': np.nan,
    'Chardonnay-Sauvignon Blanc': np.nan,
    'Castelão': np.nan,
    'Trebbiano Spoletino': np.nan,
    'Teran': np.nan,
    'Trepat': np.nan,
    'Freisa': np.nan,
    'Neuburger': np.nan,
    'Sämling': np.nan,
    'Chasselas': np.nan,
    'Hárslevelü': np.nan,
    'Trincadeira': np.nan,
    'Merlot-Tannat': np.nan,
    'Rkatsiteli': np.nan,
    'Siegerrebe': np.nan,
    'Trousseau Gris': np.nan,
    'Grenache Blend': np.nan,
    'Muscadelle': np.nan,
    'Gros Manseng': np.nan,
    'Portuguese Rosé': np.nan,
    'Lambrusco': np.nan,
    'Brachetto': np.nan,
    'Mantonico': np.nan,
    'Ekigaïna': np.nan,
    'Muskateller': np.nan,
    'Aligoté': np.nan,
    'Sangiovese Cabernet': np.nan,
    'Touriga Nacional-Cabernet Sauvignon': 'cabernet_sauvignon',
    'Muscat Blanc': np.nan,
    'Argaman': np.nan,
    'Viognier-Roussanne': np.nan,
    'Pallagrello Bianco': np.nan,
    'Bobal': np.nan,
    'Malvasia Istriana': np.nan,
    'Cabernet Sauvignon-Cabernet Franc': np.nan,
    'Baco Noir': np.nan,
    'Veltliner': np.nan,
    'Tempranillo-Tannat': np.nan,
    'Morillon': np.nan,
    'Touriga Franca': np.nan,
    'Picolit': np.nan,
    'Barbera-Nebbiolo': np.nan,
    'Prieto Picudo': np.nan,
    'Gaglioppo': np.nan,
    'Sacy': np.nan,
    'Piedirosso': np.nan,
    'Piquepoul Blanc': np.nan,
    'Mansois': np.nan,
    'Chardonnay-Sauvignon': np.nan,
    'Tempranillo-Garnacha': np.nan,
    'Carmenère-Cabernet Sauvignon': np.nan,
    'Chenin Blanc-Viognier': np.nan,
    'Susumaniello': np.nan,
    'Vitovska': np.nan,
    'Orange Muscat': np.nan,
    'Grauburgunder': np.nan,
    'Carignane': np.nan,
    'Moscatel Roxo': np.nan,
    'Tannat-Merlot': np.nan,
    'Nerello Cappuccio': np.nan,
    'Counoise': np.nan,
    'Macabeo': np.nan,
    'Mazuelo': np.nan,
    'Sauvignon-Sémillon': np.nan,
    'Tinta del Pais': np.nan,
    'Vranec': np.nan,
    'Mavrud': np.nan,
    "Cesanese d'Affile": np.nan,
    'Moscato Giallo': np.nan,
    'Verdil': np.nan,
    'Cabernet': np.nan,
    'Verduzzo Friulano ': np.nan,
    'Treixadura': np.nan,
    'Duras': np.nan,
    "Loin de l'Oeil": np.nan,
    'Coda di Volpe': np.nan,
    'Grenache-Mourvèdre': np.nan,
    'Forcallà': np.nan,
    'Viura-Verdejo': np.nan,
    'Bombino Bianco': np.nan,
    'Pinot-Chardonnay': np.nan,
    'Syrah-Tempranillo': np.nan,
    'Cabernet Sauvignon-Barbera': np.nan,
    'Merlot-Cabernet': np.nan,
    "Muscat d'Alexandrie": np.nan,
    'Jaen': np.nan,
    'Tinta del Toro': np.nan,
    'Timorasso': np.nan,
    'Pigato': np.nan,
    'Sangiovese-Cabernet Sauvignon': np.nan,
    'Shiraz-Cabernet': np.nan,
    'Viognier-Gewürztraminer': np.nan,
    'Prunelard': np.nan,
    'Sauvignon Blanc-Chenin Blanc': np.nan,
    'Gros Plant': np.nan,
    'Malbec-Petit Verdot': np.nan,
    'Colombard-Ugni Blanc': np.nan,
    'Grignolino': np.nan,
    'Garnacha-Syrah': np.nan,
    'Rufete': np.nan,
    'Pedro Ximénez': np.nan,
    'Tempranillo-Shiraz': np.nan,
    'Mtsvane': np.nan,
    'Chardonnay-Pinot Gris': np.nan,
    'Marawi': np.nan,
    'Chardonnay-Pinot Blanc': np.nan,
    'Mataro': np.nan,
    'Tinta Cao': np.nan,
    'Blauer Portugieser': np.nan,
    'Ugni Blanc': np.nan,
    'Groppello': np.nan,
    'Semillon-Chardonnay': np.nan,
    'Irsai Oliver': np.nan,
    'Raboso': np.nan,
    'Alvarelhão': np.nan,
    'Poulsard': np.nan,
    'Grenache-Shiraz': np.nan,
    'Baga-Touriga Nacional': np.nan,
    'Carineña': np.nan,
    'Pignoletto': np.nan,
    'Muscatel': np.nan,
    'Ciliegiolo': np.nan,
    'Viognier-Grenache Blanc': np.nan,
    'Greco Bianco': np.nan,
    'Cabernet Sauvignon-Merlot-Shiraz': 'merlot',
    'Sciaccerellu': np.nan,
    'Zelen': np.nan,
    'Alicante': np.nan,
    'Emir': np.nan,
    'Narince': np.nan,
    'Malbec-Cabernet': np.nan,
    'Touriga': np.nan,
    'Grecanico': np.nan,
    'Carmenère-Syrah': np.nan,
    'Madeleine Angevine': np.nan,
    'Mavroudi': np.nan,
    'Pinot Blanc-Pinot Noir': np.nan,
    'Muscat Hamburg': np.nan,
    'Tempranillo Blanco': np.nan,
    'Casavecchia': np.nan,
    'Pinot Gris-Gewürztraminer': np.nan,
    'White Riesling': np.nan,
    'Tinto Velasco': np.nan,
    'Hondarrabi Zuri': np.nan,
    'Nuragus': np.nan,
    'Xynisteri': np.nan,
    'Kadarka': np.nan,
    'Sauvignon Musqué': np.nan,
    'Roussanne-Marsanne': np.nan,
    'Incrocio Manzoni': np.nan,
    'Terrantez': np.nan,
    'Bual': np.nan,
    'Okuzgozu': np.nan,
    'Rivaner': np.nan,
    'Doña Blanca': np.nan,
    'Graševina': np.nan,
    'Sangiovese-Syrah': np.nan,
    'Tannat-Cabernet Franc': np.nan,
    'Thrapsathiri': np.nan,
    'Fer Servadou': np.nan,
    'Mission': np.nan,
    'Kekfrankos': np.nan,
    'Cococciola': np.nan,
    'Lambrusco Salamino': np.nan,
    'Blauburgunder': np.nan,
    'Marquette': np.nan,
    'Romorantin': np.nan,
    'Verdejo-Sauvignon Blanc': 'sauvignon_blanc',
    'Braucol': np.nan,
    'Malvasia-Viura': np.nan,
    'Cabernet Franc-Malbec': 'malbec',
    'Pallagrello Nero': np.nan,
    'Rebula': np.nan,
    'Vespolina': np.nan,
    'Shiraz-Malbec': 'malbec',
    'Rebo': np.nan,
    'Tempranillo-Malbec': 'malbec',
    'Tamjanika': np.nan,
    'Chinuri': np.nan,
    'Trousseau': np.nan,
    'Bacchus': np.nan,
    'Syrah-Malbec': 'malbec',
    'Syrah-Cabernet Franc': np.nan,
    'Macabeo-Moscatel': np.nan,
    'Cariñena-Garnacha': np.nan,
    'Plyto': np.nan,
    'Códega do Larinho': np.nan,
    'Sideritis': np.nan,
    'Çalkarası': np.nan,
    'Azal': np.nan,
    'Moscatel Graúdo': np.nan,
    'Viosinho': np.nan,
    'Moschofilero-Chardonnay': 'chardonnay',
    'Paralleda': np.nan,
    'Rara Neagra': np.nan,
    'Malvasia di Candia': np.nan,
    'Maria Gomes': np.nan,
    'Malvar': np.nan,
    'Airen': np.nan,
    'Erbaluce': np.nan,
    'Muscat of Alexandria': np.nan,
    'Verdosilla': np.nan,
    'Abouriou': np.nan,
    'Pinot Noir-Syrah': 'pinot_noir',
    'Nielluciu': np.nan,
    'Malbec-Bonarda': np.nan,
    'Vespaiolo': np.nan,
    'Malbec-Carménère': np.nan,
    'Biancolella': np.nan,
    'Aidani': np.nan,
    'Garnacha-Monastrell': np.nan,
    'Vinhão': np.nan,
    'Souzao': np.nan,
    'Roter Traminer': np.nan,
    'Moscatel de Alejandría': np.nan,
    'Rolle': np.nan,
    'Tinta Francisca': np.nan,
    'Malvasia Nera': np.nan,
    'Orangetraube': np.nan,
    'Riesling-Chardonnay': 'chardonnary',
    'Žilavka': np.nan,
    'Portuguiser': np.nan,
    'Listán Negro': np.nan,
    'Pinotage-Merlot': 'merlot',
    'Muscadine': np.nan,
    'Maria Gomes-Bical': np.nan,
    'Grolleau': np.nan,
    'Zlahtina': np.nan,
    'Syrah-Grenache-Viognier': np.nan,
    'Jacquez': np.nan,
    'Gouveio': np.nan,
    'Canaiolo': np.nan,
    'Carignan-Syrah': np.nan,
    'Bombino Nero': np.nan,
    'Chardonnay-Riesling': np.nan,
    'Malagouzia-Chardonnay': np.nan,
    'Mavrotragano': np.nan,
    'Bovale': np.nan,
    'Frankovka': np.nan,
    'Shiraz-Roussanne': np.nan,
    'Cabernet-Shiraz': np.nan,
    'Syrah-Carignan': np.nan,
    'Elbling': np.nan,
    'Gragnano': np.nan,
    'Mavrodaphne': np.nan,
    'Garnacha Blend': np.nan,
    'Savatiano': np.nan,
    'Schwartzriesling': np.nan,
    'Petit Meslier': np.nan,
    'Bastardo': np.nan,
    'Vidadillo': np.nan,
    'Misket': np.nan,
    'Chardonnay Weissburgunder': np.nan,
    'Macabeo-Chardonnay': np.nan,
    'Robola': np.nan,
    'Merlot-Shiraz': np.nan,
    'Malagouzia': np.nan,
    'Folle Blanche': np.nan,
    'Malbec Blend': np.nan,
    'Merlot-Syrah': np.nan,
    'Tamianka': np.nan,
    'Cabernet Pfeffer': np.nan,
    'Morio Muskat': np.nan,
    'Rabigato': np.nan,
    'Babić': np.nan,
    'Roviello': np.nan,
    'Sauvignon Blanc-Verdejo': np.nan,
    'Yapincak': np.nan,
    'Sauvignonasse': np.nan,
    'Viognier-Marsanne': np.nan,
    'Meseguera': np.nan,
    'Alvarinho-Chardonnay': np.nan,
    'Saperavi-Merlot': np.nan,
    'Pinot Blanc-Viognier': np.nan,
    'Teroldego Rotaliano': np.nan,
    'Biancu Gentile': np.nan,
    'Garnacha-Tempranillo': np.nan,
    'Xinisteri': np.nan,
    'Sauvignon Blanc-Sauvignon Gris': np.nan,
    'Trebbiano di Lugana': np.nan,
    'Albarossa': np.nan,
    'Ryzlink Rýnský': np.nan,
    'Verdeca': np.nan,
    'Cabernet Sauvignon Grenache': np.nan,
    'Tămâioasă Românească': np.nan,
    'Sherry': np.nan,
    'Merlot-Grenache': np.nan,
    'Tempranillo-Syrah': np.nan,
    'Chardonel': np.nan,
    'Silvaner-Traminer': np.nan,
    'Uvalino': np.nan,
    'Merseguera-Sauvignon Blanc': 'sauvignon_blanc',
    'Cabernet-Malbec': 'red_blend',
    'Boğazkere': np.nan,
    'Gelber Traminer': np.nan,
    'Vermentino Nero': np.nan,
    'Cayuga': np.nan,
    'Tinta Amarela': np.nan,
    'Tinta Negra Mole': np.nan,
    'Moscato Rosa': np.nan,
    'Chelois': np.nan,
    'Sauvignon Blanc-Assyrtiko': 'sauvignon_blanc',
    'Muscadel': np.nan,
    'Shiraz-Tempranillo': np.nan,
    'Roussanne-Grenache Blanc': np.nan,
    'Biancale': np.nan,
    'Ansonica': np.nan,
    'Syrah-Bonarda': np.nan,
    'Durif': np.nan,
    'Franconia': np.nan,
    'Malbec-Tempranillo': 'malbec',
    'Nasco': np.nan,
    'Monastrell-Petit Verdot': np.nan,
    'Sirica': np.nan,
    'Vital': np.nan,
    'Espadeiro': np.nan,
    'Pinot Grigio-Sauvignon Blanc': 'white-blend',
    'Blatina': np.nan,
    'Karalahna': np.nan,
    'Feteasca': np.nan,
    'Sercial': np.nan,
    'Valvin Muscat': np.nan,
    'Malvasia Fina': np.nan,
    'Roditis-Moschofilero': np.nan,
    'St. Vincent': np.nan,
    'Chancellor': np.nan,
    'Premsal': np.nan,
    'Jampal': np.nan,
    'Tokay Pinot Gris': 'pinot_gris',
    'Colorino': np.nan,
    'Picapoll': np.nan,
    'Blauburger': np.nan,
    'Tinta Madeira': np.nan,
    'Centesimino': np.nan,
    'Grenache Gris': np.nan,
    'Trajadura': np.nan,
    'Merlot-Petite Verdot': np.nan,
    'Cabernet Moravia': np.nan,
    'Catalanesca': np.nan,
    'Garnacha-Cabernet': np.nan,
    'Garnacha-Cariñena': np.nan,
    'Gamza': np.nan,
    'Cabernet Franc-Lemberger': np.nan,
    'Pinot Blanc-Chardonnay': 'chardonnay',
    'Chardonnay-Albariño': 'chardonnay',
    'Shiraz-Mourvèdre': np.nan,
    'Mavrokalavryta': np.nan,
    'Favorita': np.nan,
    'Babosa Negro': np.nan,
    'Tintilia ': np.nan,
    'Dafni': np.nan,
    'Petit Courbu': np.nan,
    'Kotsifali': np.nan,
    'Parraleta': np.nan,
    'Moscato di Noto': np.nan,
    'Roscetto': np.nan,
    'Torontel': np.nan,
    'Viognier-Valdiguié': np.nan,
    'Trollinger': np.nan,
    'Mandilaria': np.nan,
    'Francisa': np.nan,
    'Kuntra': np.nan,
    'Debit': np.nan,
    'Pignolo': np.nan,
    'Caprettone': np.nan,
    'Ondenc': np.nan,
    'Athiri': np.nan,
    'Bobal-Cabernet Sauvignon': 'cabernet_sauvignon'
}

# %%
df['variety']=df['variety'].replace(variety_dict)

# %%
df.variety.unique()
# Out:
# array(['white_blend', 'red_blend', 'pinot_grigio', 'riesling',
#        'pinot_noir', 'merlot', nan, 'cabernet_sauvignon', 'pinot noir',
#        'chardonnay', 'malbec', 'sauvignon_blanc', 'zinfandel', 'rosé', 1,
#        'chardonnary', 'white-blend', 'pinot_gris'], dtype=object)

# %%
df.variety.value_counts(dropna=False)
# Out:
# cabernet_sauvignon    21369
# red_blend             20266
# pinot_noir            18037
# chardonnay            11805
# sauvignon_blanc        7706
# riesling               7225
# NaN                    7172
# white_blend            5074
# zinfandel              3689
# merlot                 3297
# rosé                   3265
# pinot_grigio           3172
# malbec                 2625
# pinot noir               98
# chardonnary               1
# white-blend               1
# pinot_gris                1
# 1                         1
# Name: variety, dtype: int64

# %%
variety_dict2 = {
    'pinot noir' : 'pinot_noir',
    17 : 'sauvignon_blanc',
    'charonnary' : 'chardonnay',
    'pinot_gris' : 'pinot_grigio',
    'white-blend' : 'white_blend',
    1 : np.nan,
}

# %%
df['variety']=df['variety'].replace(variety_dict2)

# %%
df.dropna(inplace=True)

# %%
df.drop('title', axis=1, inplace=True)

# %%
df.to_csv('wine_data.csv', index=False)

# %%
import pandas as pd
import numpy as np
import nbimporter
from helper import *
# %run helper.ipynb
from model import *
# %run model.ipynb
import wines as w
wines = w.wines
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='whitegrid')

# %% [markdown]
# # WHAT IS THE RATING?

# %%
p = input("Where is your wine from?: ")
# Out:
# Where is your wine from?: bordeaux

# %%
g = input("What type of wine?: ")
# Out:
# What type of wine?: pinot_grigio

# %%
v = input("When was it bottled?: ")
# Out:
# When was it bottled?: 2014

# %%
m = input("How much does it cost?: ")
# Out:
# How much does it cost?: 50

# %%
generate_prediction(model, wines, p, g, int(v), int(m))
